# %% [markdown]
# # To jest początek

# %%
print("to to jest pierwszy notebook")
# Out:
# to to jest pierwszy notebook

# %%
a = 99
b = 101
a+b
print(a)
print(id(a))
# Out:
# 99
# 138890320436392

# %%
a = 12
c = 99
print(id(a))
print(id(b))
print(id(c))
# Out:
# 138890320433608
# 138890320436456
# 138890320436392

# %%
g = a+b+c
g
# Out:
# 212

# %% [markdown]
# To jest **pierwszy** notebook  -  <span>Jupyter.

# %%
lsztuk = "2"

# %%
cena = "45"

# %%
wynik = int(lsztuk) * float(cena)
wynik
# Out:
# 90.0

# %% [markdown]
# # to jest koniec programu
